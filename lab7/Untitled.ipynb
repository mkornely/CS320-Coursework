# %%
from io import StringIO
f = StringIO()
f.write("hello\n")
f.write("world!")
s = f.getvalue()
print(s)
# Out:
# hello
# world!

# %%
from matplotlib import pyplot as plt
from io import StringIO

def get_ax():
    fig, ax = plt.subplots(figsize=(8,8))
    ax.set_xlim(-8, 8)
    ax.set_ylim(-8, 8)
    ax.spines['left'].set_position('zero')
    ax.spines['bottom'].set_position('zero')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    return ax

ax = get_ax()

# "save" to a string in the SVG format
f = StringIO()
ax.get_figure().savefig(f, format="svg")
svg_data = f.getvalue()

print(svg_data)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg height="576pt" version="1.1" viewBox="0 0 576 576" width="576pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-10-25T15:39:05.901762</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.4.3, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 576
# L 576 576
# L 576 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 72 504
# L 518.4 504
# L 518.4 69.12
# L 72 69.12
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <defs>
#        <path d="M 0 0
# L 0 3.5
# " id="m927a6efb52" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72" xlink:href="#m927a6efb52" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- −8 -->
#       <g transform="translate(64.628906 301.158437)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 678 2272
# L 4684 2272
# L 4684 1741
# L 678 1741
# L 678 2272
# z
# " id="DejaVuSans-2212" transform="scale(0.015625)"/>
#         <path d="M 2034 2216
# Q 1584 2216 1326 1975
# Q 1069 1734 1069 1313
# Q 1069 891 1326 650
# Q 1584 409 2034 409
# Q 2484 409 2743 651
# Q 3003 894 3003 1313
# Q 3003 1734 2745 1975
# Q 2488 2216 2034 2216
# z
# M 1403 2484
# Q 997 2584 770 2862
# Q 544 3141 544 3541
# Q 544 4100 942 4425
# Q 1341 4750 2034 4750
# Q 2731 4750 3128 4425
# Q 3525 4100 3525 3541
# Q 3525 3141 3298 2862
# Q 3072 2584 2669 2484
# Q 3125 2378 3379 2068
# Q 3634 1759 3634 1313
# Q 3634 634 3220 271
# Q 2806 -91 2034 -91
# Q 1263 -91 848 271
# Q 434 634 434 1313
# Q 434 1759 690 2068
# Q 947 2378 1403 2484
# z
# M 1172 3481
# Q 1172 3119 1398 2916
# Q 1625 2713 2034 2713
# Q 2441 2713 2670 2916
# Q 2900 3119 2900 3481
# Q 2900 3844 2670 4047
# Q 2441 4250 2034 4250
# Q 1625 4250 1398 4047
# Q 1172 3844 1172 3481
# z
# " id="DejaVuSans-38" transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use x="83.789062" xlink:href="#DejaVuSans-38"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_2">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="127.8" xlink:href="#m927a6efb52" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- −6 -->
#       <g transform="translate(120.428906 301.158437)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 2113 2584
# Q 1688 2584 1439 2293
# Q 1191 2003 1191 1497
# Q 1191 994 1439 701
# Q 1688 409 2113 409
# Q 2538 409 2786 701
# Q 3034 994 3034 1497
# Q 3034 2003 2786 2293
# Q 2538 2584 2113 2584
# z
# M 3366 4563
# L 3366 3988
# Q 3128 4100 2886 4159
# Q 2644 4219 2406 4219
# Q 1781 4219 1451 3797
# Q 1122 3375 1075 2522
# Q 1259 2794 1537 2939
# Q 1816 3084 2150 3084
# Q 2853 3084 3261 2657
# Q 3669 2231 3669 1497
# Q 3669 778 3244 343
# Q 2819 -91 2113 -91
# Q 1303 -91 875 529
# Q 447 1150 447 2328
# Q 447 3434 972 4092
# Q 1497 4750 2381 4750
# Q 2619 4750 2861 4703
# Q 3103 4656 3366 4563
# z
# " id="DejaVuSans-36" transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use x="83.789062" xlink:href="#DejaVuSans-36"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_3">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="183.6" xlink:href="#m927a6efb52" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- −4 -->
#       <g transform="translate(176.228906 301.158437)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 2419 4116
# L 825 1625
# L 2419 1625
# L 2419 4116
# z
# M 2253 4666
# L 3047 4666
# L 3047 1625
# L 3713 1625
# L 3713 1100
# L 3047 1100
# L 3047 0
# L 2419 0
# L 2419 1100
# L 313 1100
# L 313 1709
# L 2253 4666
# z
# " id="DejaVuSans-34" transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use x="83.789062" xlink:href="#DejaVuSans-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="239.4" xlink:href="#m927a6efb52" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- −2 -->
#       <g transform="translate(232.028906 301.158437)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 1228 531
# L 3431 531
# L 3431 0
# L 469 0
# L 469 531
# Q 828 903 1448 1529
# Q 2069 2156 2228 2338
# Q 2531 2678 2651 2914
# Q 2772 3150 2772 3378
# Q 2772 3750 2511 3984
# Q 2250 4219 1831 4219
# Q 1534 4219 1204 4116
# Q 875 4013 500 3803
# L 500 4441
# Q 881 4594 1212 4672
# Q 1544 4750 1819 4750
# Q 2544 4750 2975 4387
# Q 3406 4025 3406 3419
# Q 3406 3131 3298 2873
# Q 3191 2616 2906 2266
# Q 2828 2175 2409 1742
# Q 1991 1309 1228 531
# z
# " id="DejaVuSans-32" transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use x="83.789062" xlink:href="#DejaVuSans-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#m927a6efb52" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 0 -->
#       <g transform="translate(292.01875 301.158437)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 2034 4250
# Q 1547 4250 1301 3770
# Q 1056 3291 1056 2328
# Q 1056 1369 1301 889
# Q 1547 409 2034 409
# Q 2525 409 2770 889
# Q 3016 1369 3016 2328
# Q 3016 3291 2770 3770
# Q 2525 4250 2034 4250
# z
# M 2034 4750
# Q 2819 4750 3233 4129
# Q 3647 3509 3647 2328
# Q 3647 1150 3233 529
# Q 2819 -91 2034 -91
# Q 1250 -91 836 529
# Q 422 1150 422 2328
# Q 422 3509 836 4129
# Q 1250 4750 2034 4750
# z
# " id="DejaVuSans-30" transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="351" xlink:href="#m927a6efb52" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_6">
#       <!-- 2 -->
#       <g transform="translate(347.81875 301.158437)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_7">
#      <g id="line2d_7">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="406.8" xlink:href="#m927a6efb52" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_7">
#       <!-- 4 -->
#       <g transform="translate(403.61875 301.158437)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_8">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="462.6" xlink:href="#m927a6efb52" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_8">
#       <!-- 6 -->
#       <g transform="translate(459.41875 301.158437)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-36"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_9">
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="518.4" xlink:href="#m927a6efb52" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_9">
#       <!-- 8 -->
#       <g transform="translate(515.21875 301.158437)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-38"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_10">
#       <defs>
#        <path d="M 0 0
# L -3.5 0
# " id="mc74126ee23" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#mc74126ee23" y="504"/>
#       </g>
#      </g>
#      <g id="text_10">
#       <!-- −8 -->
#       <g transform="translate(273.457812 507.799219)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use x="83.789062" xlink:href="#DejaVuSans-38"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_11">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#mc74126ee23" y="449.64"/>
#       </g>
#      </g>
#      <g id="text_11">
#       <!-- −6 -->
#       <g transform="translate(273.457812 453.439219)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use x="83.789062" xlink:href="#DejaVuSans-36"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_3">
#      <g id="line2d_12">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#mc74126ee23" y="395.28"/>
#       </g>
#      </g>
#      <g id="text_12">
#       <!-- −4 -->
#       <g transform="translate(273.457812 399.079219)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use x="83.789062" xlink:href="#DejaVuSans-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_4">
#      <g id="line2d_13">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#mc74126ee23" y="340.92"/>
#       </g>
#      </g>
#      <g id="text_13">
#       <!-- −2 -->
#       <g transform="translate(273.457812 344.719219)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use x="83.789062" xlink:href="#DejaVuSans-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_5">
#      <g id="line2d_14">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#mc74126ee23" y="286.56"/>
#       </g>
#      </g>
#      <g id="text_14">
#       <!-- 0 -->
#       <g transform="translate(281.8375 290.359219)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_6">
#      <g id="line2d_15">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#mc74126ee23" y="232.2"/>
#       </g>
#      </g>
#      <g id="text_15">
#       <!-- 2 -->
#       <g transform="translate(281.8375 235.999219)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_7">
#      <g id="line2d_16">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#mc74126ee23" y="177.84"/>
#       </g>
#      </g>
#      <g id="text_16">
#       <!-- 4 -->
#       <g transform="translate(281.8375 181.639219)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_8">
#      <g id="line2d_17">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#mc74126ee23" y="123.48"/>
#       </g>
#      </g>
#      <g id="text_17">
#       <!-- 6 -->
#       <g transform="translate(281.8375 127.279219)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-36"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_9">
#      <g id="line2d_18">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="295.2" xlink:href="#mc74126ee23" y="69.12"/>
#       </g>
#      </g>
#      <g id="text_18">
#       <!-- 8 -->
#       <g transform="translate(281.8375 72.919219)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-38"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="patch_3">
#     <path d="M 295.2 504
# L 295.2 69.12
# " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_4">
#     <path d="M 72 286.56
# L 518.4 286.56
# " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#   </g>
#  </g>
# </svg>

# %%
import requests
r = requests.post("http://34.122.10.52:5000/guess", data="16,4")
r.raise_for_status()
r.text
# Out:
# 'perfect\n'
